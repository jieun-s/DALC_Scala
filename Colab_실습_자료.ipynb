# %% [markdown]
# <a href="https://colab.research.google.com/github/jieun-s/hello-world/blob/main/Colab_%EC%8B%A4%EC%8A%B5_%EC%9E%90%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 실습 하기

# %% [markdown]
# # 새 섹션

# %% [markdown]
# ## 1. 마크다운으로 내 깃허브 링크 삽입하기
# https://github.com/jieun-s/hello-world.git
# (여기를 채워주세요! )

# %% [markdown]
# ## 2. 마크다운으로 이미지 삽입하기
# ![KakaoTalk_20180901_013713315.jpg](data:image/jpeg;base64,...)
# - 이미지는 인터넷에 있는 이미지 아무거나 또는 내 pc에 저장되어 있는 아무이미지를 삽입해주시면 됩니다.
#
# (여기를 채워주세요!)

# %% [markdown]
# ## 3. 마크다운으로 수업 배운 것 정리해보기
# - 전공수업, 교양 수업, 오늘 ot내용, 요즘 준비하는 자격증 내용 등등 기타 자기가 최근 배운 것 아무거나 최소 3줄이상 작성해주세요. (이때 단어강조하기, 문장 띄어쓰기, 인용구등 사용하기)
#
#
# (여기를 채워주세요!)
# *깃허브* 사용법이 생각보다 어려워서 초반에 좀 헤맸다.
# **정보처리기사 실기** 준비해야 하는데 책이 오늘 배송온다니까 공부는 다음주부터 해야지
# 영상을 만들어야하는 수업이 두개나 있어서 "영상편집"도 배워보려고 한다,
